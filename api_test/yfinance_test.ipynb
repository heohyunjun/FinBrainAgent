# %%
import sys
import os

# 현재 Jupyter Notebook이 실행 중인 디렉토리를 기준으로 상위 경로 추가
sys.path.append(os.path.abspath(".."))

from typing import List, Annotated, Literal, Dict, Callable, TypeVar, Tuple, Type, Generic, Optional, Any
import yfinance as yf

from sec_tool.market_data_tool import MarketDataTools, FinancialDataTools,SECFilingsTools

# %% [markdown]
# # news

# %%
def get_stock_news(ticker: Annotated[str, "Stock ticker symbol"]) -> Annotated[List[str], "List of stock news summaries"]:
    """
    Retrieves summaries of the latest news related to the given stock ticker.
    """
    stock = yf.Ticker(ticker)
    news = stock.news
    summaries = [
        item['content']['summary'] for item in news 
        if 'content' in item and 'summary' in item['content']
    ] if news else []
    return summaries

# %%
get_stock_news("TSLA")
# Out:
# ["The stock market has broken down this month as investors digest tariff and recession fears. Some of the most popular stocks such as Nvidia (NVDA), Palantir (PLTR), and Tesla have cratered. Crypto has lost its post-Trump election bid. And safe-haven stocks like healthcare have performed well. When stability will return to these top momentum names is unclear. Yahoo Finance Executive Editor Brian Sozzi talks with EvercoreISI technical strategist Rich Ross. Ross has more than 30 years of experience in studying the deepest areas of the market from a technical perspective. This experience is poised to pay off for Ross as he aims to dissect opportunities for the firm’s clients amid March’s tariff-driven sell-off.&nbsp; He shares with Sozzi some of his top trading ideas from the rubble and provides good rules of thumb for chart watchers. For full episodes of Opening Bid, listen on your favorite podcast platform or watch on our website. Yahoo Finance's Opening Bid is produced by Langston Sessoms",
#  "Tesla (TSLA) shares are down about 38% this year. But BMO Capital Markets chief investment strategist Brian Belski says investors shouldn't panic. Find out why in the video above. To watch more expert insights and analysis on the latest market action, check out more Catalysts here.",
#  'Tesla launches a free Full Self-Driving trial in China, but regulatory hurdles and stock struggles loom over its expansion plans',
#  'As Tesla (NASDAQ:TSLA) investors grow uneasy about his divided focus, Elon Musk’s past statements are resurfacing—including his claim that he never wanted to be CEO because it “hurts” his heart. Investors Question Musk’s Priorities Tesla’s stock has plummeted 52% from its mid-December high, with shares declining every week since Musk went to Washington, D.C. Investors worry that Musk is spread too thin, juggling Tesla alongside SpaceX, X, xAI, The Boring Company, Neuralink and now his role in Wa',
#  'TSLA stock has fallen for eight weeks as Elon Musk spurs Tesla brand "destruction." BYD stock is near highs as it makes a big fast-charging push.',
#  'We recently published a list of Top 10 Stocks to Buy According to Adage Capital Management. In this article, we are going to take a look at where Tesla, Inc. (NASDAQ:TSLA) stands against other top stocks to buy according to Adage Capital Management. Adage Capital Management, based in Boston, is a major investment firm specializing […]',
#  'Tesla falls Monday with shares of the electric-vehicle maker on an eight-week losing streak, while Nvidia rises as the chip maker’s GTC AI conference begins Monday.',
#  'We recently published a list of Why These 15 Automotive Stocks Have Been Plunging In 2025. In this article, we are going to take a look at where Tesla Inc (NASDAQ:TSLA) stands against other automotive stocks that have been plunging in 2025. Automotive stocks have been among the worst-performing names in the past few months, […]',
#  'We recently published a list of 10 Most Active US Stocks to Buy According to Hedge Funds. In this article, we are going to take a look at where Tesla Inc. (NASDAQ:TSLA) stands against other most active US stocks to buy according to hedge funds. Over the past five years, the U.S. stock market has […]',
#  'In a volatile market where major indexes have experienced declines for several consecutive weeks, investors are keenly observing growth companies that demonstrate resilience and potential. High insider ownership often signals confidence from those closest to the company, making it an appealing factor for investors seeking stability and growth in uncertain times.']

# %%
stock = yf.Ticker("TSLA")

# %%
stock.get_news()
# Out:
# [{'id': '77734c64-4a92-3853-beaa-1668de2400b6',
#   'content': {'id': '77734c64-4a92-3853-beaa-1668de2400b6',
#    'contentType': 'VIDEO',
#    'title': 'Are Nvidia and Tesla deeply oversold screaming buys?',
#    'description': '<p>The stock market has broken down this month as investors digest tariff and recession fears. Some of the most popular stocks such as Nvidia (<a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/quote/NVDA">NVDA</a>), Palantir (<a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/quote/PLTR">PLTR</a>), and Tesla have cratered. Crypto has lost its post-Trump election bid. And safe-haven stocks like healthcare have performed well. When stability will return to these top momentum names is unclear. Yahoo Finance Executive Editor <a data-i13n="cpos:3;pos:1" href="https://finance.yahoo.com/author/brian-sozzi/">Brian Sozzi</a> talks with EvercoreISI technical strategist Rich Ross. Ross has more than 30 years of experience in studying the deepest areas of the market from a technical perspective. This experience is poised to pay off for Ross as he aims to dissect opportunities for the firm’s clients amid March’s tariff-driven sell-off.\xa0 He shares with Sozzi some of his top trading ideas from the rubble and provides good rules of thumb for chart watchers.</p>\n<p>For full episodes of Opening Bid, <a data-i13n="cpos:4;pos:1" href="https://open.spotify.com/show/6blmkje6G8vLF8cVSWxa5A?si=13c787846e704eaa">listen</a> on your favorite podcast platform or<a data-i13n="cpos:5;pos:1" href="https://finance.yahoo.com/videos/series/opening-bid/"> watch</a> on our website.</p>\n<p><em>Yahoo Finance\'s Opening Bid is produced by Langston Sessoms</em></p>',
#    'summary': "The stock market has broken down this month as investors digest tariff and recession fears. Some of the most popular stocks such as Nvidia (NVDA), Palantir (PLTR), and Tesla have cratered. Crypto has lost its post-Trump election bid. And safe-haven stocks like healthcare have performed well. When stability will return to these top momentum names is unclear. Yahoo Finance Executive Editor Brian Sozzi talks with EvercoreISI technical strategist Rich Ross. Ross has more than 30 years of experience in studying the deepest areas of the market from a technical perspective. This experience is poised to pay off for Ross as he aims to dissect opportunities for the firm’s clients amid March’s tariff-driven sell-off.&nbsp; He shares with Sozzi some of his top trading ideas from the rubble and provides good rules of thumb for chart watchers. For full episodes of Opening Bid, listen on your favorite podcast platform or watch on our website. Yahoo Finance's Opening Bid is produced by Langston Sessoms",
#    'pubDate': '2025-03-17T12:07:44Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-03/f3786680-0326-11f0-be7f-cde282797362',
#     'originalWidth': 4000,
#     'originalHeight': 2247,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/OR3olmMxLAmhMxfEDGicpg--~B/aD0yMjQ3O3c9NDAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-03/f3786680-0326-11f0-be7f-cde282797362',
#       'width': 4000,
#       'height': 2247,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/edKeZHyp9LYzcEUlbnI_AA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-03/f3786680-0326-11f0-be7f-cde282797362',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/nvidia-tesla-deeply-oversold-screaming-120744046.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/nvidia-tesla-deeply-oversold-screaming-120744046.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '9ed8ae12-9116-32d5-be67-5b8cde4ae4a1',
#   'content': {'id': '9ed8ae12-9116-32d5-be67-5b8cde4ae4a1',
#    'contentType': 'VIDEO',
#    'title': 'Worried about Tesla stock? Take a deep breath, strategist says',
#    'description': '<p>Tesla (<a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/quote/TSLA">TSLA</a>) shares are down about 38% this year. But BMO Capital Markets chief investment strategist Brian Belski says investors shouldn\'t panic. Find out why in the video above.</p>\n<p>To watch more expert insights and analysis on the latest market action, check out more Catalysts <a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/videos/series/catalysts/">here</a>.</p>',
#    'summary': "Tesla (TSLA) shares are down about 38% this year. But BMO Capital Markets chief investment strategist Brian Belski says investors shouldn't panic. Find out why in the video above. To watch more expert insights and analysis on the latest market action, check out more Catalysts here.",
#    'pubDate': '2025-03-16T18:00:50Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-03/0a94e1c0-01d0-11f0-bbae-edfcfca08344',
#     'originalWidth': 6720,
#     'originalHeight': 3784,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yl2TdL4Zmh52mcpnj0KiDg--~B/aD0zNzg0O3c9NjcyMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-03/0a94e1c0-01d0-11f0-bbae-edfcfca08344',
#       'width': 6720,
#       'height': 3784,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/tU.lPiqYWGkGGCck0N.4yg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-03/0a94e1c0-01d0-11f0-bbae-edfcfca08344',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/worried-tesla-stock-deep-breath-180050678.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/worried-tesla-stock-deep-breath-180050678.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'ba1ae477-0493-39a6-b201-683fa2fb2ab2',
#   'content': {'id': 'ba1ae477-0493-39a6-b201-683fa2fb2ab2',
#    'contentType': 'STORY',
#    'title': "Tesla's Self-Driving Tech Faces China's Strict Rules as Stock Plunges Over 38% YTD",
#    'description': '',
#    'summary': 'Tesla launches a free Full Self-Driving trial in China, but regulatory hurdles and stock struggles loom over its expansion plans',
#    'pubDate': '2025-03-17T14:00:22Z',
#    'displayTime': '2025-03-17T14:00:22Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/us.finance.gurufocus/eaf5d2bf172126d9ce93a4d463dc0550',
#     'originalWidth': 550,
#     'originalHeight': 269,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/sNThpeB6bvcTUhaYB_rJWQ--~B/aD0yNjk7dz01NTA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/us.finance.gurufocus/eaf5d2bf172126d9ce93a4d463dc0550',
#       'width': 550,
#       'height': 269,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/rIxsQowC9zCBI0PMXGCzfw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/us.finance.gurufocus/eaf5d2bf172126d9ce93a4d463dc0550',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'GuruFocus.com',
#     'url': 'http://www.gurufocus.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/teslas-self-driving-tech-faces-140022087.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/teslas-self-driving-tech-faces-140022087.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'bd135079-b3cf-35ee-8302-a86510ac72a8',
#   'content': {'id': 'bd135079-b3cf-35ee-8302-a86510ac72a8',
#    'contentType': 'STORY',
#    'title': "With Doubts Over Musk's Tesla Commitment Growing, His Own Words Resurface—He Once Said He Never Wanted To Be CEO As It 'Hurts' His Heart",
#    'description': '',
#    'summary': 'As Tesla (NASDAQ:TSLA) investors grow uneasy about his divided focus, Elon Musk’s past statements are resurfacing—including his claim that he never wanted to be CEO because it “hurts” his heart. Investors Question Musk’s Priorities Tesla’s stock has plummeted 52% from its mid-December high, with shares declining every week since Musk went to Washington, D.C. Investors worry that Musk is spread too thin, juggling Tesla alongside SpaceX, X, xAI, The Boring Company, Neuralink and now his role in Wa',
#    'pubDate': '2025-03-17T13:45:19Z',
#    'displayTime': '2025-03-17T13:45:19Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'Benzinga', 'url': 'http://www.benzinga.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/doubts-over-musks-tesla-commitment-134519698.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/doubts-over-musks-tesla-commitment-134519698.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '29c92e28-b5ab-392e-8f22-ae525864f9e8',
#   'content': {'id': '29c92e28-b5ab-392e-8f22-ae525864f9e8',
#    'contentType': 'STORY',
#    'title': "Tesla Vs. BYD: TSLA Stock Extends Losing Streak Amid Brand 'Destruction' As BYD Charges Ahead",
#    'description': '',
#    'summary': 'TSLA stock has fallen for eight weeks as Elon Musk spurs Tesla brand "destruction." BYD stock is near highs as it makes a big fast-charging push.',
#    'pubDate': '2025-03-17T13:35:58Z',
#    'displayTime': '2025-03-17T13:35:58Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/29c92e28-b5ab-392e-8f22-ae525864f9e8/tesla-vs-byd-tsla-stock.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/ibd.com/2fb21be77237895251a58fe2d3e8803d',
#     'originalWidth': 1060,
#     'originalHeight': 599,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/jg5P4sxMGdaHn3M_b3u9rA--~B/aD01OTk7dz0xMDYwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2fb21be77237895251a58fe2d3e8803d',
#       'width': 1060,
#       'height': 599,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/0H8FkAuo1p9KVL7ZoYmjCw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/2fb21be77237895251a58fe2d3e8803d',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': "Investor's Business Daily",
#     'url': 'http://www.investors.com/'},
#    'canonicalUrl': {'url': 'https://www.investors.com/news/tesla-vs-byd-ev-sales-robotaxis/?src=A00220&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '4601c84e-df2a-3fe4-bd1a-b360d0ea4aa8',
#   'content': {'id': '4601c84e-df2a-3fe4-bd1a-b360d0ea4aa8',
#    'contentType': 'STORY',
#    'title': 'Is Tesla, Inc. (TSLA) the Top Stock to Buy According to Adage Capital Management?',
#    'description': '',
#    'summary': 'We recently published a list of Top 10 Stocks to Buy According to Adage Capital Management. In this article, we are going to take a look at where Tesla, Inc. (NASDAQ:TSLA) stands against other top stocks to buy according to Adage Capital Management. Adage Capital Management, based in Boston, is a major investment firm specializing […]',
#    'pubDate': '2025-03-17T13:31:42Z',
#    'displayTime': '2025-03-17T13:31:42Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#     'originalWidth': 1456,
#     'originalHeight': 816,
#     'caption': 'Is Tesla, Inc. (TSLA) the Top Stock to Buy According to Adage Capital Management?',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/EkxYwM8q9K2Yn7hOukra6A--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 1456,
#       'height': 816,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/dXoTFxAiaENntffRoJeDVA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-top-stock-133142477.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-top-stock-133142477.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '66300462-6e37-399e-a6cf-afe911d99558',
#   'content': {'id': '66300462-6e37-399e-a6cf-afe911d99558',
#    'contentType': 'STORY',
#    'title': 'These Stocks Are Moving the Most Today: Tesla, Nvidia, Affirm, Baidu, Norwegian Cruise Line, Micron, and More',
#    'description': '',
#    'summary': 'Tesla falls Monday with shares of the electric-vehicle maker on an eight-week losing streak, while Nvidia rises as the chip maker’s GTC AI conference begins Monday.',
#    'pubDate': '2025-03-17T11:45:00Z',
#    'displayTime': '2025-03-17T11:45:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/66300462-6e37-399e-a6cf-afe911d99558/these-stocks-are-moving-the.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/Barrons.com/288f0020dfcc5e25373428ad80537d9f',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/faqG2yAjINOQhayrw.x6Eg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/288f0020dfcc5e25373428ad80537d9f',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/htS5EzOqdky7f9Rf3zR4Eg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/Barrons.com/288f0020dfcc5e25373428ad80537d9f',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Barrons.com',
#     'url': 'http://www.barrons.com/'},
#    'canonicalUrl': {'url': 'https://www.barrons.com/articles/stock-market-movers-1ee6a697?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '86e6af0f-15f3-3f10-9cf5-af05f814cc4f',
#   'content': {'id': '86e6af0f-15f3-3f10-9cf5-af05f814cc4f',
#    'contentType': 'STORY',
#    'title': 'Why Tesla Inc (TSLA) Is Plunging In 2025?',
#    'description': '',
#    'summary': 'We recently published a list of Why These 15 Automotive Stocks Have Been Plunging In 2025. In this article, we are going to take a look at where Tesla Inc (NASDAQ:TSLA) stands against other automotive stocks that have been plunging in 2025. Automotive stocks have been among the worst-performing names in the past few months, […]',
#    'pubDate': '2025-03-17T11:31:20Z',
#    'displayTime': '2025-03-17T11:31:20Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#     'originalWidth': 1456,
#     'originalHeight': 816,
#     'caption': 'Why Tesla Inc (TSLA) Is Plunging In 2025?',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/EkxYwM8q9K2Yn7hOukra6A--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 1456,
#       'height': 816,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/dXoTFxAiaENntffRoJeDVA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/why-tesla-inc-tsla-plunging-113120103.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/why-tesla-inc-tsla-plunging-113120103.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '1e131fa0-416c-3fb6-ac09-974280bb610b',
#   'content': {'id': '1e131fa0-416c-3fb6-ac09-974280bb610b',
#    'contentType': 'STORY',
#    'title': 'Is Tesla Inc. (TSLA) the Most Active US Stock to Buy According to Hedge Funds?',
#    'description': '',
#    'summary': 'We recently published a list of 10 Most Active US Stocks to Buy According to Hedge Funds. In this article, we are going to take a look at where Tesla Inc. (NASDAQ:TSLA) stands against other most active US stocks to buy according to hedge funds. Over the past five years, the U.S. stock market has […]',
#    'pubDate': '2025-03-17T11:27:54Z',
#    'displayTime': '2025-03-17T11:27:54Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/729d273415e0fad2bd8a0ece46ffd0a7',
#     'originalWidth': 1200,
#     'originalHeight': 800,
#     'caption': 'Is Tesla Inc. (TSLA) the Most Active US Stock to Buy According to Hedge Funds?',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LMkkll61ocHQBaNrRXCPZw--~B/aD04MDA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/729d273415e0fad2bd8a0ece46ffd0a7',
#       'width': 1200,
#       'height': 800,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/0q0m9ubvVlhpnUPyb1Wy4Q--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/729d273415e0fad2bd8a0ece46ffd0a7',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-most-active-112754645.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-most-active-112754645.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '7d67bd1f-8418-3ff8-8aa0-b96f1b3aa824',
#   'content': {'id': '7d67bd1f-8418-3ff8-8aa0-b96f1b3aa824',
#    'contentType': 'STORY',
#    'title': '3 Growth Companies With High Insider Ownership Achieving 17% Revenue Growth',
#    'description': '',
#    'summary': 'In a volatile market where major indexes have experienced declines for several consecutive weeks, investors are keenly observing growth companies that demonstrate resilience and potential. High insider ownership often signals confidence from those closest to the company, making it an appealing factor for investors seeking stability and growth in uncertain times.',
#    'pubDate': '2025-03-17T11:05:42Z',
#    'displayTime': '2025-03-17T11:05:42Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/simply_wall_st__316/f154d96e707b72662bb943262df39179',
#     'originalWidth': 1194,
#     'originalHeight': 432,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/QGLovWAwWCv8nrG8MWbT.g--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/f154d96e707b72662bb943262df39179',
#       'width': 1194,
#       'height': 432,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/aS2RTdiximrYIFruWqaGeQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/simply_wall_st__316/f154d96e707b72662bb943262df39179',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Simply Wall St.',
#     'url': 'https://simplywall.st/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/3-growth-companies-high-insider-110542482.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/3-growth-companies-high-insider-110542482.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
stock.news
# Out:
# [{'id': '77734c64-4a92-3853-beaa-1668de2400b6',
#   'content': {'id': '77734c64-4a92-3853-beaa-1668de2400b6',
#    'contentType': 'VIDEO',
#    'title': 'Are Nvidia and Tesla deeply oversold screaming buys?',
#    'description': '<p>The stock market has broken down this month as investors digest tariff and recession fears. Some of the most popular stocks such as Nvidia (<a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/quote/NVDA">NVDA</a>), Palantir (<a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/quote/PLTR">PLTR</a>), and Tesla have cratered. Crypto has lost its post-Trump election bid. And safe-haven stocks like healthcare have performed well. When stability will return to these top momentum names is unclear. Yahoo Finance Executive Editor <a data-i13n="cpos:3;pos:1" href="https://finance.yahoo.com/author/brian-sozzi/">Brian Sozzi</a> talks with EvercoreISI technical strategist Rich Ross. Ross has more than 30 years of experience in studying the deepest areas of the market from a technical perspective. This experience is poised to pay off for Ross as he aims to dissect opportunities for the firm’s clients amid March’s tariff-driven sell-off.\xa0 He shares with Sozzi some of his top trading ideas from the rubble and provides good rules of thumb for chart watchers.</p>\n<p>For full episodes of Opening Bid, <a data-i13n="cpos:4;pos:1" href="https://open.spotify.com/show/6blmkje6G8vLF8cVSWxa5A?si=13c787846e704eaa">listen</a> on your favorite podcast platform or<a data-i13n="cpos:5;pos:1" href="https://finance.yahoo.com/videos/series/opening-bid/"> watch</a> on our website.</p>\n<p><em>Yahoo Finance\'s Opening Bid is produced by Langston Sessoms</em></p>',
#    'summary': "The stock market has broken down this month as investors digest tariff and recession fears. Some of the most popular stocks such as Nvidia (NVDA), Palantir (PLTR), and Tesla have cratered. Crypto has lost its post-Trump election bid. And safe-haven stocks like healthcare have performed well. When stability will return to these top momentum names is unclear. Yahoo Finance Executive Editor Brian Sozzi talks with EvercoreISI technical strategist Rich Ross. Ross has more than 30 years of experience in studying the deepest areas of the market from a technical perspective. This experience is poised to pay off for Ross as he aims to dissect opportunities for the firm’s clients amid March’s tariff-driven sell-off.&nbsp; He shares with Sozzi some of his top trading ideas from the rubble and provides good rules of thumb for chart watchers. For full episodes of Opening Bid, listen on your favorite podcast platform or watch on our website. Yahoo Finance's Opening Bid is produced by Langston Sessoms",
#    'pubDate': '2025-03-17T12:07:44Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-03/f3786680-0326-11f0-be7f-cde282797362',
#     'originalWidth': 4000,
#     'originalHeight': 2247,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/OR3olmMxLAmhMxfEDGicpg--~B/aD0yMjQ3O3c9NDAwMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-03/f3786680-0326-11f0-be7f-cde282797362',
#       'width': 4000,
#       'height': 2247,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/edKeZHyp9LYzcEUlbnI_AA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-03/f3786680-0326-11f0-be7f-cde282797362',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/nvidia-tesla-deeply-oversold-screaming-120744046.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/nvidia-tesla-deeply-oversold-screaming-120744046.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '9ed8ae12-9116-32d5-be67-5b8cde4ae4a1',
#   'content': {'id': '9ed8ae12-9116-32d5-be67-5b8cde4ae4a1',
#    'contentType': 'VIDEO',
#    'title': 'Worried about Tesla stock? Take a deep breath, strategist says',
#    'description': '<p>Tesla (<a data-i13n="cpos:1;pos:1" href="https://finance.yahoo.com/quote/TSLA">TSLA</a>) shares are down about 38% this year. But BMO Capital Markets chief investment strategist Brian Belski says investors shouldn\'t panic. Find out why in the video above.</p>\n<p>To watch more expert insights and analysis on the latest market action, check out more Catalysts <a data-i13n="cpos:2;pos:1" href="https://finance.yahoo.com/videos/series/catalysts/">here</a>.</p>',
#    'summary': "Tesla (TSLA) shares are down about 38% this year. But BMO Capital Markets chief investment strategist Brian Belski says investors shouldn't panic. Find out why in the video above. To watch more expert insights and analysis on the latest market action, check out more Catalysts here.",
#    'pubDate': '2025-03-16T18:00:50Z',
#    'displayTime': '',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://s.yimg.com/os/creatr-uploaded-images/2025-03/0a94e1c0-01d0-11f0-bbae-edfcfca08344',
#     'originalWidth': 6720,
#     'originalHeight': 3784,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/yl2TdL4Zmh52mcpnj0KiDg--~B/aD0zNzg0O3c9NjcyMDthcHBpZD15dGFjaHlvbg--/https://s.yimg.com/os/creatr-uploaded-images/2025-03/0a94e1c0-01d0-11f0-bbae-edfcfca08344',
#       'width': 6720,
#       'height': 3784,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/tU.lPiqYWGkGGCck0N.4yg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://s.yimg.com/os/creatr-uploaded-images/2025-03/0a94e1c0-01d0-11f0-bbae-edfcfca08344',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Yahoo Finance Video',
#     'url': 'https://finance.yahoo.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/video/worried-tesla-stock-deep-breath-180050678.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/video/worried-tesla-stock-deep-breath-180050678.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': True},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'ba1ae477-0493-39a6-b201-683fa2fb2ab2',
#   'content': {'id': 'ba1ae477-0493-39a6-b201-683fa2fb2ab2',
#    'contentType': 'STORY',
#    'title': "Tesla's Self-Driving Tech Faces China's Strict Rules as Stock Plunges Over 38% YTD",
#    'description': '',
#    'summary': 'Tesla launches a free Full Self-Driving trial in China, but regulatory hurdles and stock struggles loom over its expansion plans',
#    'pubDate': '2025-03-17T14:00:22Z',
#    'displayTime': '2025-03-17T14:00:22Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/us.finance.gurufocus/eaf5d2bf172126d9ce93a4d463dc0550',
#     'originalWidth': 550,
#     'originalHeight': 269,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/sNThpeB6bvcTUhaYB_rJWQ--~B/aD0yNjk7dz01NTA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/us.finance.gurufocus/eaf5d2bf172126d9ce93a4d463dc0550',
#       'width': 550,
#       'height': 269,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/rIxsQowC9zCBI0PMXGCzfw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/us.finance.gurufocus/eaf5d2bf172126d9ce93a4d463dc0550',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'GuruFocus.com',
#     'url': 'http://www.gurufocus.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/teslas-self-driving-tech-faces-140022087.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/teslas-self-driving-tech-faces-140022087.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': 'bd135079-b3cf-35ee-8302-a86510ac72a8',
#   'content': {'id': 'bd135079-b3cf-35ee-8302-a86510ac72a8',
#    'contentType': 'STORY',
#    'title': "With Doubts Over Musk's Tesla Commitment Growing, His Own Words Resurface—He Once Said He Never Wanted To Be CEO As It 'Hurts' His Heart",
#    'description': '',
#    'summary': 'As Tesla (NASDAQ:TSLA) investors grow uneasy about his divided focus, Elon Musk’s past statements are resurfacing—including his claim that he never wanted to be CEO because it “hurts” his heart. Investors Question Musk’s Priorities Tesla’s stock has plummeted 52% from its mid-December high, with shares declining every week since Musk went to Washington, D.C. Investors worry that Musk is spread too thin, juggling Tesla alongside SpaceX, X, xAI, The Boring Company, Neuralink and now his role in Wa',
#    'pubDate': '2025-03-17T13:45:19Z',
#    'displayTime': '2025-03-17T13:45:19Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': None,
#    'provider': {'displayName': 'Benzinga', 'url': 'http://www.benzinga.com/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/doubts-over-musks-tesla-commitment-134519698.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/doubts-over-musks-tesla-commitment-134519698.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '29c92e28-b5ab-392e-8f22-ae525864f9e8',
#   'content': {'id': '29c92e28-b5ab-392e-8f22-ae525864f9e8',
#    'contentType': 'STORY',
#    'title': "Tesla Vs. BYD: TSLA Stock Extends Losing Streak Amid Brand 'Destruction' As BYD Charges Ahead",
#    'description': '',
#    'summary': 'TSLA stock has fallen for eight weeks as Elon Musk spurs Tesla brand "destruction." BYD stock is near highs as it makes a big fast-charging push.',
#    'pubDate': '2025-03-17T13:35:58Z',
#    'displayTime': '2025-03-17T13:35:58Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/29c92e28-b5ab-392e-8f22-ae525864f9e8/tesla-vs-byd-tsla-stock.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/ibd.com/2fb21be77237895251a58fe2d3e8803d',
#     'originalWidth': 1060,
#     'originalHeight': 599,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/jg5P4sxMGdaHn3M_b3u9rA--~B/aD01OTk7dz0xMDYwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/ibd.com/2fb21be77237895251a58fe2d3e8803d',
#       'width': 1060,
#       'height': 599,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/0H8FkAuo1p9KVL7ZoYmjCw--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/ibd.com/2fb21be77237895251a58fe2d3e8803d',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': "Investor's Business Daily",
#     'url': 'http://www.investors.com/'},
#    'canonicalUrl': {'url': 'https://www.investors.com/news/tesla-vs-byd-ev-sales-robotaxis/?src=A00220&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '4601c84e-df2a-3fe4-bd1a-b360d0ea4aa8',
#   'content': {'id': '4601c84e-df2a-3fe4-bd1a-b360d0ea4aa8',
#    'contentType': 'STORY',
#    'title': 'Is Tesla, Inc. (TSLA) the Top Stock to Buy According to Adage Capital Management?',
#    'description': '',
#    'summary': 'We recently published a list of Top 10 Stocks to Buy According to Adage Capital Management. In this article, we are going to take a look at where Tesla, Inc. (NASDAQ:TSLA) stands against other top stocks to buy according to Adage Capital Management. Adage Capital Management, based in Boston, is a major investment firm specializing […]',
#    'pubDate': '2025-03-17T13:31:42Z',
#    'displayTime': '2025-03-17T13:31:42Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#     'originalWidth': 1456,
#     'originalHeight': 816,
#     'caption': 'Is Tesla, Inc. (TSLA) the Top Stock to Buy According to Adage Capital Management?',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/EkxYwM8q9K2Yn7hOukra6A--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 1456,
#       'height': 816,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/dXoTFxAiaENntffRoJeDVA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-top-stock-133142477.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-top-stock-133142477.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '66300462-6e37-399e-a6cf-afe911d99558',
#   'content': {'id': '66300462-6e37-399e-a6cf-afe911d99558',
#    'contentType': 'STORY',
#    'title': 'These Stocks Are Moving the Most Today: Tesla, Nvidia, Affirm, Baidu, Norwegian Cruise Line, Micron, and More',
#    'description': '',
#    'summary': 'Tesla falls Monday with shares of the electric-vehicle maker on an eight-week losing streak, while Nvidia rises as the chip maker’s GTC AI conference begins Monday.',
#    'pubDate': '2025-03-17T11:45:00Z',
#    'displayTime': '2025-03-17T11:45:00Z',
#    'isHosted': False,
#    'bypassModal': False,
#    'previewUrl': 'https://finance.yahoo.com/m/66300462-6e37-399e-a6cf-afe911d99558/these-stocks-are-moving-the.html',
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/Barrons.com/288f0020dfcc5e25373428ad80537d9f',
#     'originalWidth': 1280,
#     'originalHeight': 640,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/faqG2yAjINOQhayrw.x6Eg--~B/aD02NDA7dz0xMjgwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/Barrons.com/288f0020dfcc5e25373428ad80537d9f',
#       'width': 1280,
#       'height': 640,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/htS5EzOqdky7f9Rf3zR4Eg--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/Barrons.com/288f0020dfcc5e25373428ad80537d9f',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Barrons.com',
#     'url': 'http://www.barrons.com/'},
#    'canonicalUrl': {'url': 'https://www.barrons.com/articles/stock-market-movers-1ee6a697?siteid=yhoof2&yptr=yahoo',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': None,
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '86e6af0f-15f3-3f10-9cf5-af05f814cc4f',
#   'content': {'id': '86e6af0f-15f3-3f10-9cf5-af05f814cc4f',
#    'contentType': 'STORY',
#    'title': 'Why Tesla Inc (TSLA) Is Plunging In 2025?',
#    'description': '',
#    'summary': 'We recently published a list of Why These 15 Automotive Stocks Have Been Plunging In 2025. In this article, we are going to take a look at where Tesla Inc (NASDAQ:TSLA) stands against other automotive stocks that have been plunging in 2025. Automotive stocks have been among the worst-performing names in the past few months, […]',
#    'pubDate': '2025-03-17T11:31:20Z',
#    'displayTime': '2025-03-17T11:31:20Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#     'originalWidth': 1456,
#     'originalHeight': 816,
#     'caption': 'Why Tesla Inc (TSLA) Is Plunging In 2025?',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/EkxYwM8q9K2Yn7hOukra6A--~B/aD04MTY7dz0xNDU2O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 1456,
#       'height': 816,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/dXoTFxAiaENntffRoJeDVA--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/1277c6032fd09b727a10249a170024cf',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/why-tesla-inc-tsla-plunging-113120103.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/why-tesla-inc-tsla-plunging-113120103.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '1e131fa0-416c-3fb6-ac09-974280bb610b',
#   'content': {'id': '1e131fa0-416c-3fb6-ac09-974280bb610b',
#    'contentType': 'STORY',
#    'title': 'Is Tesla Inc. (TSLA) the Most Active US Stock to Buy According to Hedge Funds?',
#    'description': '',
#    'summary': 'We recently published a list of 10 Most Active US Stocks to Buy According to Hedge Funds. In this article, we are going to take a look at where Tesla Inc. (NASDAQ:TSLA) stands against other most active US stocks to buy according to hedge funds. Over the past five years, the U.S. stock market has […]',
#    'pubDate': '2025-03-17T11:27:54Z',
#    'displayTime': '2025-03-17T11:27:54Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/insidermonkey.com/729d273415e0fad2bd8a0ece46ffd0a7',
#     'originalWidth': 1200,
#     'originalHeight': 800,
#     'caption': 'Is Tesla Inc. (TSLA) the Most Active US Stock to Buy According to Hedge Funds?',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/LMkkll61ocHQBaNrRXCPZw--~B/aD04MDA7dz0xMjAwO2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/insidermonkey.com/729d273415e0fad2bd8a0ece46ffd0a7',
#       'width': 1200,
#       'height': 800,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/0q0m9ubvVlhpnUPyb1Wy4Q--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/insidermonkey.com/729d273415e0fad2bd8a0ece46ffd0a7',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Insider Monkey',
#     'url': 'http://www.insidermonkey.com'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-most-active-112754645.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/tesla-inc-tsla-most-active-112754645.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}},
#  {'id': '7d67bd1f-8418-3ff8-8aa0-b96f1b3aa824',
#   'content': {'id': '7d67bd1f-8418-3ff8-8aa0-b96f1b3aa824',
#    'contentType': 'STORY',
#    'title': '3 Growth Companies With High Insider Ownership Achieving 17% Revenue Growth',
#    'description': '',
#    'summary': 'In a volatile market where major indexes have experienced declines for several consecutive weeks, investors are keenly observing growth companies that demonstrate resilience and potential. High insider ownership often signals confidence from those closest to the company, making it an appealing factor for investors seeking stability and growth in uncertain times.',
#    'pubDate': '2025-03-17T11:05:42Z',
#    'displayTime': '2025-03-17T11:05:42Z',
#    'isHosted': True,
#    'bypassModal': False,
#    'previewUrl': None,
#    'thumbnail': {'originalUrl': 'https://media.zenfs.com/en/simply_wall_st__316/f154d96e707b72662bb943262df39179',
#     'originalWidth': 1194,
#     'originalHeight': 432,
#     'caption': '',
#     'resolutions': [{'url': 'https://s.yimg.com/uu/api/res/1.2/QGLovWAwWCv8nrG8MWbT.g--~B/aD00MzI7dz0xMTk0O2FwcGlkPXl0YWNoeW9u/https://media.zenfs.com/en/simply_wall_st__316/f154d96e707b72662bb943262df39179',
#       'width': 1194,
#       'height': 432,
#       'tag': 'original'},
#      {'url': 'https://s.yimg.com/uu/api/res/1.2/aS2RTdiximrYIFruWqaGeQ--~B/Zmk9c3RyaW07aD0xMjg7dz0xNzA7YXBwaWQ9eXRhY2h5b24-/https://media.zenfs.com/en/simply_wall_st__316/f154d96e707b72662bb943262df39179',
#       'width': 170,
#       'height': 128,
#       'tag': '170x128'}]},
#    'provider': {'displayName': 'Simply Wall St.',
#     'url': 'https://simplywall.st/'},
#    'canonicalUrl': {'url': 'https://finance.yahoo.com/news/3-growth-companies-high-insider-110542482.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'clickThroughUrl': {'url': 'https://finance.yahoo.com/news/3-growth-companies-high-insider-110542482.html',
#     'site': 'finance',
#     'region': 'US',
#     'lang': 'en-US'},
#    'metadata': {'editorsPick': False},
#    'finance': {'premiumFinance': {'isPremiumNews': False,
#      'isPremiumFreeNews': False}},
#    'storyline': None}}]

# %%
stock.get_recommendations_summary()
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   15    15     9           2
# 1    -1m          7   14    15     9           3
# 2    -2m          7   13    15     8           4
# 3    -3m          7   13    15     8           5

# %%
stock.get_recommendations()
# Out:
#   period  strongBuy  buy  hold  sell  strongSell
# 0     0m          7   15    15     9           2
# 1    -1m          7   14    15     9           3
# 2    -2m          7   13    15     8           4
# 3    -3m          7   13    15     8           5

# %%
stock.get_insider_transactions()
# Out:
#      Shares       Value URL  \
# 0    531787  12992693.0
# 1     54776  13189403.0
# 2      2672    718111.0
# 3      6538         NaN
# 4      6000    109320.0
# ..      ...         ...  ..
# 114    3750    739912.0
# 115  100000   2473000.0
# 116  100000  19573464.0
# 117   10500    219555.0
# 118   10500   2040780.0
#
#                                                   Text               Insider  \
# 0    Conversion of Exercise of derivative security ...  MURDOCH JAMES RUPERT
# 1                      Sale at price 240.79 per share.  MURDOCH JAMES RUPERT
# 2                      Sale at price 268.73 per share.        TANEJA VAIBHAV
# 3                                                             TANEJA VAIBHAV
# 4    Conversion of Exercise of derivative security ...        TANEJA VAIBHAV
# ..                                                 ...                   ...
# 114                    Sale at price 197.31 per share.      KIRKHORN ZACHARY
# 115  Conversion of Exercise of derivative security ...         MUSK KIMBAL J
# 116           Sale at price 192.78 - 202.64 per share.         MUSK KIMBAL J
# 117  Conversion of Exercise of derivative security ...      BAGLINO ANDREW D
# 118                    Sale at price 194.36 per share.      BAGLINO ANDREW D
#
#                     Position Transaction Start Date Ownership
# 0                   Director             2025-03-10         D
# 1                   Director             2025-03-10         D
# 2    Chief Financial Officer             2025-03-06         D
# 3    Chief Financial Officer             2025-03-05         D
# 4    Chief Financial Officer             2025-03-03         D
# ..                       ...         ...        ...       ...
# 114  Chief Financial Officer             2023-04-04         D
# 115                 Director             2023-04-03         D
# 116                 Director             2023-04-03         D
# 117                  Officer             2023-03-27         D
# 118                  Officer             2023-03-27         D
#
# [119 rows x 9 columns]

# %%
stock.get_analyst_price_targets()
# Out:
# {'current': 241.865,
#  'high': 550.0,
#  'low': 120.0,
#  'mean': 343.1064,
#  'median': 376.5}

# %%
stock.insider_transactions
# Out:
#      Shares       Value URL  \
# 0    531787  12992693.0
# 1     54776  13189403.0
# 2      2672    718111.0
# 3      6538         NaN
# 4      6000    109320.0
# ..      ...         ...  ..
# 114    3750    739912.0
# 115  100000   2473000.0
# 116  100000  19573464.0
# 117   10500    219555.0
# 118   10500   2040780.0
#
#                                                   Text               Insider  \
# 0    Conversion of Exercise of derivative security ...  MURDOCH JAMES RUPERT
# 1                      Sale at price 240.79 per share.  MURDOCH JAMES RUPERT
# 2                      Sale at price 268.73 per share.        TANEJA VAIBHAV
# 3                                                             TANEJA VAIBHAV
# 4    Conversion of Exercise of derivative security ...        TANEJA VAIBHAV
# ..                                                 ...                   ...
# 114                    Sale at price 197.31 per share.      KIRKHORN ZACHARY
# 115  Conversion of Exercise of derivative security ...         MUSK KIMBAL J
# 116           Sale at price 192.78 - 202.64 per share.         MUSK KIMBAL J
# 117  Conversion of Exercise of derivative security ...      BAGLINO ANDREW D
# 118                    Sale at price 194.36 per share.      BAGLINO ANDREW D
#
#                     Position Transaction Start Date Ownership
# 0                   Director             2025-03-10         D
# 1                   Director             2025-03-10         D
# 2    Chief Financial Officer             2025-03-06         D
# 3    Chief Financial Officer             2025-03-05         D
# 4    Chief Financial Officer             2025-03-03         D
# ..                       ...         ...        ...       ...
# 114  Chief Financial Officer             2023-04-04         D
# 115                 Director             2023-04-03         D
# 116                 Director             2023-04-03         D
# 117                  Officer             2023-03-27         D
# 118                  Officer             2023-03-27         D
#
# [119 rows x 9 columns]

# %%
stock.insider_transactions.loc[0]['Text']
# Out:
# 'Conversion of Exercise of derivative security at price 23.85 - 24.73 per share.'

# %%
stock.get_institutional_holders()
# Out:
#   Date Reported                             Holder  pctHeld     Shares  \
# 0    2024-12-31                 Vanguard Group Inc   0.0756  243193181
# 1    2024-12-31                     Blackrock Inc.   0.0629  202186537
# 2    2024-12-31           State Street Corporation   0.0349  112211396
# 3    2024-12-31      Geode Capital Management, LLC   0.0190   61011604
# 4    2024-12-31                     Morgan Stanley   0.0140   44967162
# 5    2024-12-31            Capital World Investors   0.0128   41219130
# 6    2024-12-31          JP Morgan Chase & Company   0.0112   35989404
# 7    2024-12-31  Norges Bank Investment Management   0.0111   35707824
# 8    2024-12-31                           FMR, LLC   0.0108   34661400
# 9    2024-12-31         Northern Trust Corporation   0.0089   28579615
#
#          Value  pctChange
# 0  58811407406     0.0149
# 1  48894770612     0.0382
# 2  27136082100     0.0045
# 3  14754436307     0.0279
# 4  10874408868     0.1228
# 5   9968022283    -0.0372
# 6   8703317635     0.1346
# 7   8635223143     0.1582
# 8   8382166425     0.4010
# 9   6911408347     0.2159

# %%
stock.get_actions()
# Out:
#                            Dividends  Stock Splits
# Date
# 2020-08-31 00:00:00-04:00        0.0           5.0
# 2022-08-25 00:00:00-04:00        0.0           3.0

# %%
stock_info = yf.download("TSLA", period='1d').to_dict()
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed

# %%
stock_info
# Out:
# {('Close', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 238.8990020751953},
#  ('High', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 245.0399932861328},
#  ('Low', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 238.7801055908203},
#  ('Open', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 244.97000122070312},
#  ('Volume', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 29261665}}

# %%
stock_info = yf.download("TSLA", period='1d').to_dict()
stock_info
# Out:
# [*********************100%***********************]  1 of 1 completed
# {('Close', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 238.07000732421875},
#  ('High', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 245.0399932861328},
#  ('Low', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 237.5},
#  ('Open', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 244.97000122070312},
#  ('Volume', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 30183189}}

# %%
from langchain.tools import tool

@tool
def get_stock_price(ticker: str, period: str = "1d", start: str = None, end: str = None) -> dict:
    """
    주어진 주식 티커에 대해 지정된 기간의 가격 데이터를 반환합니다.

    Args:
        ticker (str): 다운로드할 주식 티커. 단일 문자열로 제공 (예: "AAPL").
        period (str): 데이터를 가져올 기간. 유효한 값: "1d", "5d", "1mo", "3mo", "6mo", "1y", "2y", "5y", "10y", "ytd", "max".
                    기본값은 "1d". "period"를 사용하거나 "start"와 "end"를 사용해야 함. 두 가지를 동시에 사용할 수 없음.
        start (str, optional): 데이터 다운로드 시작 날짜(포함). 형식: "YYYY-MM-DD". 예: "2020-01-01".
                            "period" 대신 사용할 수 있으며, 기본값은 None (99년 전부터).
        end (str, optional): 데이터 다운로드 종료 날짜(미포함). 형식: "YYYY-MM-DD". 예: "2023-01-01" (마지막 데이터는 "2022-12-31").
                            "period" 대신 사용할 수 있으며, 기본값은 None (현재 날짜까지).

    Returns:
        dict: 지정된 티커에 대한 주식 가격 데이터를 딕셔너리 형태로 반환.
    """
    stock_info = yf.download(ticker, period=period, start=start, end=end).to_dict()
    return stock_info

# %%
get_stock_price.invoke("TSLA")
# Out:
# YF.download() has changed argument auto_adjust default to True
# [*********************100%***********************]  1 of 1 completed
# keys must be str, int, float, bool or None, not tuple
# Error in LangChainTracer.on_tool_end callback: TypeError('keys must be str, int, float, bool or None, not tuple')
# {('Close', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 238.00999450683594},
#  ('High', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 245.0399932861328},
#  ('Low', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 232.8000946044922},
#  ('Open', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 244.97000122070312},
#  ('Volume', 'TSLA'): {Timestamp('2025-03-17 00:00:00'): 110592050}}

# %% [markdown]
# # financials

# %%
company_info = yf.Ticker("TSLA")

# %%
financial_info = company_info.get_financials(freq = 'quarterly')

# %%
company_info.get_income_stmt(freq = 'quarterly')
# Out:
#                                                            2024-12-31  \
# TaxEffectOfUnusualItems                               -1098336.948662
# TaxRateForCalcs                                              0.156905
# NormalizedEBITDA                                         4365000000.0
# TotalUnusualItems                                          -7000000.0
# TotalUnusualItemsExcludingGoodwill                         -7000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...       2356000000.0
# ReconciledDepreciation                                   1496000000.0
# ReconciledCostOfRevenue                                 21528000000.0
# EBITDA                                                   4358000000.0
# EBIT                                                     2862000000.0
# NetInterestIncome                                         346000000.0
# InterestExpense                                            96000000.0
# InterestIncome                                            442000000.0
# NormalizedIncome                                    2361901663.051338
# NetIncomeFromContinuingAndDiscontinuedOperation          2356000000.0
# TotalExpenses                                           24117000000.0
# RentExpenseSupplemental                                   242000000.0
# TotalOperatingIncomeAsReported                           1583000000.0
# DilutedAverageShares                                              NaN
# BasicAverageShares                                                NaN
# DilutedEPS                                                        NaN
# BasicEPS                                                          NaN
# DilutedNIAvailtoComStockholders                          2314000000.0
# AverageDilutionEarnings                                           NaN
# NetIncomeCommonStockholders                              2314000000.0
# OtherunderPreferredStockDividend                                  NaN
# NetIncome                                                2356000000.0
# MinorityInterests                                          24000000.0
# NetIncomeIncludingNoncontrollingInterests                2332000000.0
# NetIncomeContinuousOperations                            2332000000.0
# TaxProvision                                              434000000.0
# PretaxIncome                                             2766000000.0
# OtherIncomeExpense                                        830000000.0
# OtherNonOperatingIncomeExpenses                           837000000.0
# SpecialIncomeCharges                                       -7000000.0
# RestructuringAndMergernAcquisition                          7000000.0
# NetNonOperatingInterestIncomeExpense                      346000000.0
# InterestExpenseNonOperating                                96000000.0
# InterestIncomeNonOperating                                442000000.0
# OperatingIncome                                          1590000000.0
# OperatingExpense                                         2589000000.0
# ResearchAndDevelopment                                   1276000000.0
# SellingGeneralAndAdministration                          1313000000.0
# GrossProfit                                              4179000000.0
# CostOfRevenue                                           21528000000.0
# TotalRevenue                                            25707000000.0
# OperatingRevenue                                        25707000000.0
#
#                                                        2024-09-30  \
# TaxEffectOfUnusualItems                               -12100000.0
# TaxRateForCalcs                                              0.22
# NormalizedEBITDA                                     4279000000.0
# TotalUnusualItems                                     -55000000.0
# TotalUnusualItemsExcludingGoodwill                    -55000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   2167000000.0
# ReconciledDepreciation                               1348000000.0
# ReconciledCostOfRevenue                             20185000000.0
# EBITDA                                               4224000000.0
# EBIT                                                 2876000000.0
# NetInterestIncome                                     337000000.0
# InterestExpense                                        92000000.0
# InterestIncome                                        429000000.0
# NormalizedIncome                                     2209900000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      2167000000.0
# TotalExpenses                                       22410000000.0
# RentExpenseSupplemental                               247000000.0
# TotalOperatingIncomeAsReported                       2717000000.0
# DilutedAverageShares                                 3497000000.0
# BasicAverageShares                                   3198000000.0
# DilutedEPS                                                   0.62
# BasicEPS                                                     0.68
# DilutedNIAvailtoComStockholders                      2167000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          2167000000.0
# OtherunderPreferredStockDividend                              0.0
# NetIncome                                            2167000000.0
# MinorityInterests                                     -16000000.0
# NetIncomeIncludingNoncontrollingInterests            2183000000.0
# NetIncomeContinuousOperations                        2183000000.0
# TaxProvision                                          601000000.0
# PretaxIncome                                         2784000000.0
# OtherIncomeExpense                                   -325000000.0
# OtherNonOperatingIncomeExpenses                      -270000000.0
# SpecialIncomeCharges                                  -55000000.0
# RestructuringAndMergernAcquisition                     55000000.0
# NetNonOperatingInterestIncomeExpense                  337000000.0
# InterestExpenseNonOperating                            92000000.0
# InterestIncomeNonOperating                            429000000.0
# OperatingIncome                                      2772000000.0
# OperatingExpense                                     2225000000.0
# ResearchAndDevelopment                               1039000000.0
# SellingGeneralAndAdministration                      1186000000.0
# GrossProfit                                          4997000000.0
# CostOfRevenue                                       20185000000.0
# TotalRevenue                                        25182000000.0
# OperatingRevenue                                    25182000000.0
#
#                                                        2024-06-30  \
# TaxEffectOfUnusualItems                              -130620000.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                     3873000000.0
# TotalUnusualItems                                    -622000000.0
# TotalUnusualItemsExcludingGoodwill                   -622000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   1478000000.0
# ReconciledDepreciation                               1278000000.0
# ReconciledCostOfRevenue                             20922000000.0
# EBITDA                                               3251000000.0
# EBIT                                                 1973000000.0
# NetInterestIncome                                     262000000.0
# InterestExpense                                        86000000.0
# InterestIncome                                        348000000.0
# NormalizedIncome                                     1969380000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      1478000000.0
# TotalExpenses                                       23273000000.0
# RentExpenseSupplemental                               245000000.0
# TotalOperatingIncomeAsReported                       1605000000.0
# DilutedAverageShares                                 3481000000.0
# BasicAverageShares                                   3191000000.0
# DilutedEPS                                                   0.42
# BasicEPS                                                     0.46
# DilutedNIAvailtoComStockholders                      1478000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          1478000000.0
# OtherunderPreferredStockDividend                              NaN
# NetIncome                                            1478000000.0
# MinorityInterests                                     -16000000.0
# NetIncomeIncludingNoncontrollingInterests            1494000000.0
# NetIncomeContinuousOperations                        1494000000.0
# TaxProvision                                          393000000.0
# PretaxIncome                                         1887000000.0
# OtherIncomeExpense                                   -602000000.0
# OtherNonOperatingIncomeExpenses                        20000000.0
# SpecialIncomeCharges                                 -622000000.0
# RestructuringAndMergernAcquisition                    622000000.0
# NetNonOperatingInterestIncomeExpense                  262000000.0
# InterestExpenseNonOperating                            86000000.0
# InterestIncomeNonOperating                            348000000.0
# OperatingIncome                                      2227000000.0
# OperatingExpense                                     2351000000.0
# ResearchAndDevelopment                               1074000000.0
# SellingGeneralAndAdministration                      1277000000.0
# GrossProfit                                          4578000000.0
# CostOfRevenue                                       20922000000.0
# TotalRevenue                                        25500000000.0
# OperatingRevenue                                    25500000000.0
#
#                                                        2024-03-31  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                              0.26
# NormalizedEBITDA                                     2875000000.0
# TotalUnusualItems                                             NaN
# TotalUnusualItemsExcludingGoodwill                            NaN
# NetIncomeFromContinuingOperationNetMinorityInte...   1129000000.0
# ReconciledDepreciation                               1246000000.0
# ReconciledCostOfRevenue                             17605000000.0
# EBITDA                                               2875000000.0
# EBIT                                                 1629000000.0
# NetInterestIncome                                     274000000.0
# InterestExpense                                        76000000.0
# InterestIncome                                        350000000.0
# NormalizedIncome                                     1129000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      1129000000.0
# TotalExpenses                                       20130000000.0
# RentExpenseSupplemental                               269000000.0
# TotalOperatingIncomeAsReported                       1171000000.0
# DilutedAverageShares                                 3484000000.0
# BasicAverageShares                                   3186000000.0
# DilutedEPS                                                   0.34
# BasicEPS                                                     0.37
# DilutedNIAvailtoComStockholders                      1171000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          1171000000.0
# OtherunderPreferredStockDividend                      -42000000.0
# NetIncome                                            1129000000.0
# MinorityInterests                                     -15000000.0
# NetIncomeIncludingNoncontrollingInterests            1144000000.0
# NetIncomeContinuousOperations                        1144000000.0
# TaxProvision                                          409000000.0
# PretaxIncome                                         1553000000.0
# OtherIncomeExpense                                    108000000.0
# OtherNonOperatingIncomeExpenses                       108000000.0
# SpecialIncomeCharges                                          NaN
# RestructuringAndMergernAcquisition                            NaN
# NetNonOperatingInterestIncomeExpense                  274000000.0
# InterestExpenseNonOperating                            76000000.0
# InterestIncomeNonOperating                            350000000.0
# OperatingIncome                                      1171000000.0
# OperatingExpense                                     2525000000.0
# ResearchAndDevelopment                               1151000000.0
# SellingGeneralAndAdministration                      1374000000.0
# GrossProfit                                          3696000000.0
# CostOfRevenue                                       17605000000.0
# TotalRevenue                                        21301000000.0
# OperatingRevenue                                    21301000000.0
#
#                                                        2023-12-31  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                     3484000000.0
# TotalUnusualItems                                             0.0
# TotalUnusualItemsExcludingGoodwill                            0.0
# NetIncomeFromContinuingOperationNetMinorityInte...   7930000000.0
# ReconciledDepreciation                               1232000000.0
# ReconciledCostOfRevenue                             20729000000.0
# EBITDA                                               3484000000.0
# EBIT                                                 2252000000.0
# NetInterestIncome                                     272000000.0
# InterestExpense                                        61000000.0
# InterestIncome                                        333000000.0
# NormalizedIncome                                     7930000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      7930000000.0
# TotalExpenses                                       23103000000.0
# RentExpenseSupplemental                               296000000.0
# TotalOperatingIncomeAsReported                       2064000000.0
# DilutedAverageShares                                 3492000000.0
# BasicAverageShares                                   3181000000.0
# DilutedEPS                                                   2.27
# BasicEPS                                                     2.49
# DilutedNIAvailtoComStockholders                      7927000000.0
# AverageDilutionEarnings                                       0.0
# NetIncomeCommonStockholders                          7927000000.0
# OtherunderPreferredStockDividend                              NaN
# NetIncome                                            7930000000.0
# MinorityInterests                                     -13000000.0
# NetIncomeIncludingNoncontrollingInterests            7943000000.0
# NetIncomeContinuousOperations                        7943000000.0
# TaxProvision                                        -5752000000.0
# PretaxIncome                                         2191000000.0
# OtherIncomeExpense                                   -145000000.0
# OtherNonOperatingIncomeExpenses                      -145000000.0
# SpecialIncomeCharges                                          0.0
# RestructuringAndMergernAcquisition                            0.0
# NetNonOperatingInterestIncomeExpense                  272000000.0
# InterestExpenseNonOperating                            61000000.0
# InterestIncomeNonOperating                            333000000.0
# OperatingIncome                                      2064000000.0
# OperatingExpense                                     2374000000.0
# ResearchAndDevelopment                               1094000000.0
# SellingGeneralAndAdministration                      1280000000.0
# GrossProfit                                          4438000000.0
# CostOfRevenue                                       20729000000.0
# TotalRevenue                                        25167000000.0
# OperatingRevenue                                    25167000000.0
#
#                                                       2023-09-30 2023-06-30
# TaxEffectOfUnusualItems                                      NaN        NaN
# TaxRateForCalcs                                              NaN        NaN
# NormalizedEBITDA                                             NaN        NaN
# TotalUnusualItems                                            0.0        NaN
# TotalUnusualItemsExcludingGoodwill                           0.0        NaN
# NetIncomeFromContinuingOperationNetMinorityInte...           NaN        NaN
# ReconciledDepreciation                                       NaN        NaN
# ReconciledCostOfRevenue                                      NaN        NaN
# EBITDA                                                       NaN        NaN
# EBIT                                                         NaN        NaN
# NetInterestIncome                                            NaN        NaN
# InterestExpense                                              NaN        NaN
# InterestIncome                                               NaN        NaN
# NormalizedIncome                                             NaN        NaN
# NetIncomeFromContinuingAndDiscontinuedOperation              NaN        NaN
# TotalExpenses                                                NaN        NaN
# RentExpenseSupplemental                                      NaN        NaN
# TotalOperatingIncomeAsReported                               NaN        NaN
# DilutedAverageShares                                3493000000.0        NaN
# BasicAverageShares                                  3176000000.0        NaN
# DilutedEPS                                                  0.53        NaN
# BasicEPS                                                    0.58        NaN
# DilutedNIAvailtoComStockholders                              NaN        NaN
# AverageDilutionEarnings                                      0.0        0.0
# NetIncomeCommonStockholders                                  NaN        NaN
# OtherunderPreferredStockDividend                       2000000.0        0.0
# NetIncome                                                    NaN        NaN
# MinorityInterests                                            NaN        NaN
# NetIncomeIncludingNoncontrollingInterests                    NaN        NaN
# NetIncomeContinuousOperations                                NaN        NaN
# TaxProvision                                                 NaN        NaN
# PretaxIncome                                                 NaN        NaN
# OtherIncomeExpense                                           NaN        NaN
# OtherNonOperatingIncomeExpenses                              NaN        NaN
# SpecialIncomeCharges                                         0.0        NaN
# RestructuringAndMergernAcquisition                           0.0        NaN
# NetNonOperatingInterestIncomeExpense                         NaN        NaN
# InterestExpenseNonOperating                                  NaN        NaN
# InterestIncomeNonOperating                                   NaN        NaN
# OperatingIncome                                              NaN        NaN
# OperatingExpense                                             NaN        NaN
# ResearchAndDevelopment                                       NaN        NaN
# SellingGeneralAndAdministration                              NaN        NaN
# GrossProfit                                                  NaN        NaN
# CostOfRevenue                                                NaN        NaN
# TotalRevenue                                                 NaN        NaN
# OperatingRevenue                                             NaN        NaN

# %%
financial_info
# Out:
#                                                            2024-12-31  \
# TaxEffectOfUnusualItems                               -1098336.948662
# TaxRateForCalcs                                              0.156905
# NormalizedEBITDA                                         4365000000.0
# TotalUnusualItems                                          -7000000.0
# TotalUnusualItemsExcludingGoodwill                         -7000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...       2356000000.0
# ReconciledDepreciation                                   1496000000.0
# ReconciledCostOfRevenue                                 21528000000.0
# EBITDA                                                   4358000000.0
# EBIT                                                     2862000000.0
# NetInterestIncome                                         346000000.0
# InterestExpense                                            96000000.0
# InterestIncome                                            442000000.0
# NormalizedIncome                                    2361901663.051338
# NetIncomeFromContinuingAndDiscontinuedOperation          2356000000.0
# TotalExpenses                                           24117000000.0
# RentExpenseSupplemental                                   242000000.0
# TotalOperatingIncomeAsReported                           1583000000.0
# DilutedAverageShares                                              NaN
# BasicAverageShares                                                NaN
# DilutedEPS                                                        NaN
# BasicEPS                                                          NaN
# DilutedNIAvailtoComStockholders                          2314000000.0
# AverageDilutionEarnings                                           NaN
# NetIncomeCommonStockholders                              2314000000.0
# OtherunderPreferredStockDividend                                  NaN
# NetIncome                                                2356000000.0
# MinorityInterests                                          24000000.0
# NetIncomeIncludingNoncontrollingInterests                2332000000.0
# NetIncomeContinuousOperations                            2332000000.0
# TaxProvision                                              434000000.0
# PretaxIncome                                             2766000000.0
# OtherIncomeExpense                                        830000000.0
# OtherNonOperatingIncomeExpenses                           837000000.0
# SpecialIncomeCharges                                       -7000000.0
# RestructuringAndMergernAcquisition                          7000000.0
# NetNonOperatingInterestIncomeExpense                      346000000.0
# InterestExpenseNonOperating                                96000000.0
# InterestIncomeNonOperating                                442000000.0
# OperatingIncome                                          1590000000.0
# OperatingExpense                                         2589000000.0
# ResearchAndDevelopment                                   1276000000.0
# SellingGeneralAndAdministration                          1313000000.0
# GrossProfit                                              4179000000.0
# CostOfRevenue                                           21528000000.0
# TotalRevenue                                            25707000000.0
# OperatingRevenue                                        25707000000.0
#
#                                                        2024-09-30  \
# TaxEffectOfUnusualItems                               -12100000.0
# TaxRateForCalcs                                              0.22
# NormalizedEBITDA                                     4279000000.0
# TotalUnusualItems                                     -55000000.0
# TotalUnusualItemsExcludingGoodwill                    -55000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   2167000000.0
# ReconciledDepreciation                               1348000000.0
# ReconciledCostOfRevenue                             20185000000.0
# EBITDA                                               4224000000.0
# EBIT                                                 2876000000.0
# NetInterestIncome                                     337000000.0
# InterestExpense                                        92000000.0
# InterestIncome                                        429000000.0
# NormalizedIncome                                     2209900000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      2167000000.0
# TotalExpenses                                       22410000000.0
# RentExpenseSupplemental                               247000000.0
# TotalOperatingIncomeAsReported                       2717000000.0
# DilutedAverageShares                                 3497000000.0
# BasicAverageShares                                   3198000000.0
# DilutedEPS                                                   0.62
# BasicEPS                                                     0.68
# DilutedNIAvailtoComStockholders                      2167000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          2167000000.0
# OtherunderPreferredStockDividend                              0.0
# NetIncome                                            2167000000.0
# MinorityInterests                                     -16000000.0
# NetIncomeIncludingNoncontrollingInterests            2183000000.0
# NetIncomeContinuousOperations                        2183000000.0
# TaxProvision                                          601000000.0
# PretaxIncome                                         2784000000.0
# OtherIncomeExpense                                   -325000000.0
# OtherNonOperatingIncomeExpenses                      -270000000.0
# SpecialIncomeCharges                                  -55000000.0
# RestructuringAndMergernAcquisition                     55000000.0
# NetNonOperatingInterestIncomeExpense                  337000000.0
# InterestExpenseNonOperating                            92000000.0
# InterestIncomeNonOperating                            429000000.0
# OperatingIncome                                      2772000000.0
# OperatingExpense                                     2225000000.0
# ResearchAndDevelopment                               1039000000.0
# SellingGeneralAndAdministration                      1186000000.0
# GrossProfit                                          4997000000.0
# CostOfRevenue                                       20185000000.0
# TotalRevenue                                        25182000000.0
# OperatingRevenue                                    25182000000.0
#
#                                                        2024-06-30  \
# TaxEffectOfUnusualItems                              -130620000.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                     3873000000.0
# TotalUnusualItems                                    -622000000.0
# TotalUnusualItemsExcludingGoodwill                   -622000000.0
# NetIncomeFromContinuingOperationNetMinorityInte...   1478000000.0
# ReconciledDepreciation                               1278000000.0
# ReconciledCostOfRevenue                             20922000000.0
# EBITDA                                               3251000000.0
# EBIT                                                 1973000000.0
# NetInterestIncome                                     262000000.0
# InterestExpense                                        86000000.0
# InterestIncome                                        348000000.0
# NormalizedIncome                                     1969380000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      1478000000.0
# TotalExpenses                                       23273000000.0
# RentExpenseSupplemental                               245000000.0
# TotalOperatingIncomeAsReported                       1605000000.0
# DilutedAverageShares                                 3481000000.0
# BasicAverageShares                                   3191000000.0
# DilutedEPS                                                   0.42
# BasicEPS                                                     0.46
# DilutedNIAvailtoComStockholders                      1478000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          1478000000.0
# OtherunderPreferredStockDividend                              NaN
# NetIncome                                            1478000000.0
# MinorityInterests                                     -16000000.0
# NetIncomeIncludingNoncontrollingInterests            1494000000.0
# NetIncomeContinuousOperations                        1494000000.0
# TaxProvision                                          393000000.0
# PretaxIncome                                         1887000000.0
# OtherIncomeExpense                                   -602000000.0
# OtherNonOperatingIncomeExpenses                        20000000.0
# SpecialIncomeCharges                                 -622000000.0
# RestructuringAndMergernAcquisition                    622000000.0
# NetNonOperatingInterestIncomeExpense                  262000000.0
# InterestExpenseNonOperating                            86000000.0
# InterestIncomeNonOperating                            348000000.0
# OperatingIncome                                      2227000000.0
# OperatingExpense                                     2351000000.0
# ResearchAndDevelopment                               1074000000.0
# SellingGeneralAndAdministration                      1277000000.0
# GrossProfit                                          4578000000.0
# CostOfRevenue                                       20922000000.0
# TotalRevenue                                        25500000000.0
# OperatingRevenue                                    25500000000.0
#
#                                                        2024-03-31  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                              0.26
# NormalizedEBITDA                                     2875000000.0
# TotalUnusualItems                                             NaN
# TotalUnusualItemsExcludingGoodwill                            NaN
# NetIncomeFromContinuingOperationNetMinorityInte...   1129000000.0
# ReconciledDepreciation                               1246000000.0
# ReconciledCostOfRevenue                             17605000000.0
# EBITDA                                               2875000000.0
# EBIT                                                 1629000000.0
# NetInterestIncome                                     274000000.0
# InterestExpense                                        76000000.0
# InterestIncome                                        350000000.0
# NormalizedIncome                                     1129000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      1129000000.0
# TotalExpenses                                       20130000000.0
# RentExpenseSupplemental                               269000000.0
# TotalOperatingIncomeAsReported                       1171000000.0
# DilutedAverageShares                                 3484000000.0
# BasicAverageShares                                   3186000000.0
# DilutedEPS                                                   0.34
# BasicEPS                                                     0.37
# DilutedNIAvailtoComStockholders                      1171000000.0
# AverageDilutionEarnings                                       NaN
# NetIncomeCommonStockholders                          1171000000.0
# OtherunderPreferredStockDividend                      -42000000.0
# NetIncome                                            1129000000.0
# MinorityInterests                                     -15000000.0
# NetIncomeIncludingNoncontrollingInterests            1144000000.0
# NetIncomeContinuousOperations                        1144000000.0
# TaxProvision                                          409000000.0
# PretaxIncome                                         1553000000.0
# OtherIncomeExpense                                    108000000.0
# OtherNonOperatingIncomeExpenses                       108000000.0
# SpecialIncomeCharges                                          NaN
# RestructuringAndMergernAcquisition                            NaN
# NetNonOperatingInterestIncomeExpense                  274000000.0
# InterestExpenseNonOperating                            76000000.0
# InterestIncomeNonOperating                            350000000.0
# OperatingIncome                                      1171000000.0
# OperatingExpense                                     2525000000.0
# ResearchAndDevelopment                               1151000000.0
# SellingGeneralAndAdministration                      1374000000.0
# GrossProfit                                          3696000000.0
# CostOfRevenue                                       17605000000.0
# TotalRevenue                                        21301000000.0
# OperatingRevenue                                    21301000000.0
#
#                                                        2023-12-31  \
# TaxEffectOfUnusualItems                                       0.0
# TaxRateForCalcs                                              0.21
# NormalizedEBITDA                                     3484000000.0
# TotalUnusualItems                                             0.0
# TotalUnusualItemsExcludingGoodwill                            0.0
# NetIncomeFromContinuingOperationNetMinorityInte...   7930000000.0
# ReconciledDepreciation                               1232000000.0
# ReconciledCostOfRevenue                             20729000000.0
# EBITDA                                               3484000000.0
# EBIT                                                 2252000000.0
# NetInterestIncome                                     272000000.0
# InterestExpense                                        61000000.0
# InterestIncome                                        333000000.0
# NormalizedIncome                                     7930000000.0
# NetIncomeFromContinuingAndDiscontinuedOperation      7930000000.0
# TotalExpenses                                       23103000000.0
# RentExpenseSupplemental                               296000000.0
# TotalOperatingIncomeAsReported                       2064000000.0
# DilutedAverageShares                                 3492000000.0
# BasicAverageShares                                   3181000000.0
# DilutedEPS                                                   2.27
# BasicEPS                                                     2.49
# DilutedNIAvailtoComStockholders                      7927000000.0
# AverageDilutionEarnings                                       0.0
# NetIncomeCommonStockholders                          7927000000.0
# OtherunderPreferredStockDividend                              NaN
# NetIncome                                            7930000000.0
# MinorityInterests                                     -13000000.0
# NetIncomeIncludingNoncontrollingInterests            7943000000.0
# NetIncomeContinuousOperations                        7943000000.0
# TaxProvision                                        -5752000000.0
# PretaxIncome                                         2191000000.0
# OtherIncomeExpense                                   -145000000.0
# OtherNonOperatingIncomeExpenses                      -145000000.0
# SpecialIncomeCharges                                          0.0
# RestructuringAndMergernAcquisition                            0.0
# NetNonOperatingInterestIncomeExpense                  272000000.0
# InterestExpenseNonOperating                            61000000.0
# InterestIncomeNonOperating                            333000000.0
# OperatingIncome                                      2064000000.0
# OperatingExpense                                     2374000000.0
# ResearchAndDevelopment                               1094000000.0
# SellingGeneralAndAdministration                      1280000000.0
# GrossProfit                                          4438000000.0
# CostOfRevenue                                       20729000000.0
# TotalRevenue                                        25167000000.0
# OperatingRevenue                                    25167000000.0
#
#                                                       2023-09-30 2023-06-30
# TaxEffectOfUnusualItems                                      NaN        NaN
# TaxRateForCalcs                                              NaN        NaN
# NormalizedEBITDA                                             NaN        NaN
# TotalUnusualItems                                            0.0        NaN
# TotalUnusualItemsExcludingGoodwill                           0.0        NaN
# NetIncomeFromContinuingOperationNetMinorityInte...           NaN        NaN
# ReconciledDepreciation                                       NaN        NaN
# ReconciledCostOfRevenue                                      NaN        NaN
# EBITDA                                                       NaN        NaN
# EBIT                                                         NaN        NaN
# NetInterestIncome                                            NaN        NaN
# InterestExpense                                              NaN        NaN
# InterestIncome                                               NaN        NaN
# NormalizedIncome                                             NaN        NaN
# NetIncomeFromContinuingAndDiscontinuedOperation              NaN        NaN
# TotalExpenses                                                NaN        NaN
# RentExpenseSupplemental                                      NaN        NaN
# TotalOperatingIncomeAsReported                               NaN        NaN
# DilutedAverageShares                                3493000000.0        NaN
# BasicAverageShares                                  3176000000.0        NaN
# DilutedEPS                                                  0.53        NaN
# BasicEPS                                                    0.58        NaN
# DilutedNIAvailtoComStockholders                              NaN        NaN
# AverageDilutionEarnings                                      0.0        0.0
# NetIncomeCommonStockholders                                  NaN        NaN
# OtherunderPreferredStockDividend                       2000000.0        0.0
# NetIncome                                                    NaN        NaN
# MinorityInterests                                            NaN        NaN
# NetIncomeIncludingNoncontrollingInterests                    NaN        NaN
# NetIncomeContinuousOperations                                NaN        NaN
# TaxProvision                                                 NaN        NaN
# PretaxIncome                                                 NaN        NaN
# OtherIncomeExpense                                           NaN        NaN
# OtherNonOperatingIncomeExpenses                              NaN        NaN
# SpecialIncomeCharges                                         0.0        NaN
# RestructuringAndMergernAcquisition                           0.0        NaN
# NetNonOperatingInterestIncomeExpense                         NaN        NaN
# InterestExpenseNonOperating                                  NaN        NaN
# InterestIncomeNonOperating                                   NaN        NaN
# OperatingIncome                                              NaN        NaN
# OperatingExpense                                             NaN        NaN
# ResearchAndDevelopment                                       NaN        NaN
# SellingGeneralAndAdministration                              NaN        NaN
# GrossProfit                                                  NaN        NaN
# CostOfRevenue                                                NaN        NaN
# TotalRevenue                                                 NaN        NaN
# OperatingRevenue                                             NaN        NaN

# %%
filtered_financial_info = FinancialDataTools.filter_financial_info(financial_info)

# %%
filtered_financial_info
# Out:
#                     2024-12-31     2024-09-30     2024-06-30     2024-03-31  \
# EBITDA            4358000000.0   4224000000.0   3251000000.0   2875000000.0
# EBIT              2862000000.0   2876000000.0   1973000000.0   1629000000.0
# InterestExpense     96000000.0     92000000.0     86000000.0     76000000.0
# DilutedEPS                 NaN           0.62           0.42           0.34
# BasicEPS                   NaN           0.68           0.46           0.37
# NetIncome         2356000000.0   2167000000.0   1478000000.0   1129000000.0
# TaxProvision       434000000.0    601000000.0    393000000.0    409000000.0
# OperatingIncome   1590000000.0   2772000000.0   2227000000.0   1171000000.0
# GrossProfit       4179000000.0   4997000000.0   4578000000.0   3696000000.0
# CostOfRevenue    21528000000.0  20185000000.0  20922000000.0  17605000000.0
# TotalRevenue     25707000000.0  25182000000.0  25500000000.0  21301000000.0
#
#                     2023-12-31 2023-09-30 2023-06-30
# EBITDA            3484000000.0        NaN        NaN
# EBIT              2252000000.0        NaN        NaN
# InterestExpense     61000000.0        NaN        NaN
# DilutedEPS                2.27       0.53        NaN
# BasicEPS                  2.49       0.58        NaN
# NetIncome         7930000000.0        NaN        NaN
# TaxProvision     -5752000000.0        NaN        NaN
# OperatingIncome   2064000000.0        NaN        NaN
# GrossProfit       4438000000.0        NaN        NaN
# CostOfRevenue    20729000000.0        NaN        NaN
# TotalRevenue     25167000000.0        NaN        NaN

# %%
type(filtered_financial_info)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# # Sec_fillings

# %%
company_info = yf.Ticker("TSLA")
sec_filings = company_info.get_sec_filings()

# %%
sec_filings[0]
# Out:
# {'date': datetime.date(2025, 1, 30),
#  'epochDate': 1738195200,
#  'type': '10-K',
#  'title': 'Periodic Financial Reports',
#  'edgarUrl': 'https://finance.yahoo.com/sec-filing/TSLA/0001628280-25-003063_1318605',
#  'exhibits': {'10-K': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-20241231.htm',
#   'EX-4.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/ex41.htm',
#   'EXCEL': 'https://s3.amazonaws.com/finance-pri-uw2/sec-filings/0001318605/000162828025003063/Financial_Report.xlsx',
#   'EX-19': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex19.htm',
#   'EX-21.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex211.htm',
#   'EX-23.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex231.htm',
#   'EX-31.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex311.htm',
#   'EX-31.2': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex312.htm',
#   'EX-32.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex321.htm',
#   'EX-4.72': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000162828025003063/tsla-2024x12x31xex472.htm'},
#  'maxAge': 1}

# %%
sec_filings[-1]
# Out:
# {'date': datetime.date(2021, 4, 27),
#  'epochDate': 1619481600,
#  'type': 'CORRESP',
#  'title': 'A correspondence can be sent as a document with another submission type or can be sent as a separate submission',
#  'edgarUrl': 'https://finance.yahoo.com/sec-filing/TSLA/0001193125-21-134954_1318605',
#  'exhibits': {'CORRESP': 'https://cdn.yahoofinance.com/prod/sec-filings/0001318605/000119312521134954/filename1.htm'},
#  'maxAge': 1}

# %%
unique_types = {d['type'] for d in sec_filings if 'type' in d}
print(unique_types)
# Out:
# {'10-K', 'PX14A6G', 'SD', '8-K/A', 'DEF 14A', 'DEFA14A', '10-Q', '8-K', 'SC 13G/A', 'ARS', '10-K/A', 'CORRESP', 'PRE 14A'}

# %%
from collections import Counter
type_counter = Counter(d.get('type') for d in sec_filings if 'type' in d)
print(type_counter)
# Out:
# Counter({'8-K': 34, 'DEFA14A': 26, '10-Q': 9, 'SC 13G/A': 8, 'CORRESP': 6, '10-K': 4, 'PX14A6G': 4, 'PRE 14A': 2, 'SD': 2, 'DEF 14A': 1, '8-K/A': 1, 'ARS': 1, '10-K/A': 1})

# %%
appl_company_info = yf.Ticker("AAPL")
appl_sec_filings = appl_company_info.get_sec_filings()
type_counter = Counter(d.get('type') for d in appl_sec_filings if 'type' in d)
print(type_counter)
# Out:
# Counter({'8-K': 24, '10-Q': 9, 'SC 13G/A': 5, 'PX14A6G': 4, '10-K': 3, 'CORRESP': 3, 'DEFA14A': 3, 'SD': 2, 'DEF 14A': 1, '25-NSE': 1, 'PX14A6N': 1})

# %%
appl_sec_filings[0]
# Out:
# {'date': datetime.date(2025, 2, 25),
#  'epochDate': 1740441600,
#  'type': '8-K',
#  'title': 'Corporate Changes & Voting Matters',
#  'edgarUrl': 'https://finance.yahoo.com/sec-filing/AAPL/0001140361-25-005876_320193',
#  'exhibits': {'EXCEL': 'https://s3.amazonaws.com/finance-pri-uw2/sec-filings/0000320193/000114036125005876/Financial_Report.xlsx',
#   '8-K': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000114036125005876/ef20044022_8k.htm'},
#  'maxAge': 1}

# %%
appl_sec_filings[1]
# Out:
# {'date': datetime.date(2025, 1, 31),
#  'epochDate': 1738281600,
#  'type': '10-Q',
#  'title': 'Periodic Financial Reports',
#  'edgarUrl': 'https://finance.yahoo.com/sec-filing/AAPL/0000320193-25-000008_320193',
#  'exhibits': {'10-Q': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000008/aapl-20241228.htm',
#   'EX-10.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000008/a10-qexhibit10112282024.htm',
#   'EX-10.2': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000008/a10-qexhibit10212282024.htm',
#   'EX-31.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000008/a10-qexhibit31112282024.htm',
#   'EX-31.2': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000008/a10-qexhibit31212282024.htm',
#   'EX-32.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000008/a10-qexhibit32112282024.htm',
#   'EXCEL': 'https://s3.amazonaws.com/finance-pri-uw2/sec-filings/0000320193/000032019325000008/Financial_Report.xlsx'},
#  'maxAge': 1}

# %%
appl_sec_filings[2]
# Out:
# {'date': datetime.date(2025, 1, 30),
#  'epochDate': 1738195200,
#  'type': '8-K',
#  'title': 'Corporate Changes & Voting Matters',
#  'edgarUrl': 'https://finance.yahoo.com/sec-filing/AAPL/0000320193-25-000007_320193',
#  'exhibits': {'EX-99.1': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000007/a8-kex991q1202512282024.htm',
#   'EXCEL': 'https://s3.amazonaws.com/finance-pri-uw2/sec-filings/0000320193/000032019325000007/Financial_Report.xlsx',
#   '8-K': 'https://cdn.yahoofinance.com/prod/sec-filings/0000320193/000032019325000007/aapl-20250130.htm'},
#  'maxAge': 1}

# %%
msft_company_info = yf.Ticker("MSFT")
msft_sec_filings = msft_company_info.get_sec_filings()

msft_type_counter = Counter(d.get('type') for d in msft_sec_filings if 'type' in d)
print(msft_type_counter)
# Out:
# Counter({'8-K': 20, 'PX14A6G': 8, '10-Q': 7, '11-K': 6, 'SC 13G/A': 5, 'CORRESP': 3, 'SD': 3, '10-K': 2, 'S-3ASR': 1, 'ARS': 1, '8-K/A': 1, 'DEF 14A': 1, 'DEFA14A': 1})

# %%
def get_financial_event_filings(ticker: str) -> dict:
    """
    주어진 티커에 대해 회사의 재무 보고 및 주요 사건 관련 SEC 제출 자료를 반환합니다.
    대상 문서 유형: '10-K', '10-Q', '8-K', '10-K/A', '10-Q/A', '8-K/A', '20-F', '6-K'.

    Args:
        ticker (str): 조회할 주식 티커. 단일 문자열로 제공 (예: "AAPL").

    Returns:
        dict: 지정된 유형의 SEC 제출 자료를 필터링한 결과. 키는 'financial_event_filings'이며, 값은 필터링된 리스트.
    """
    # 대상 문서 유형 정의
    target_types = {'10-K', '10-Q', '8-K', '10-K/A', '10-Q/A', '8-K/A', '20-F', '6-K'}

    # SEC 제출 자료 가져오기
    company_info = yf.Ticker(ticker)
    sec_filings = company_info.get_sec_filings()

    # 리스트에서 대상 유형만 필터링
    filtered_filings = [filing for filing in sec_filings if filing.get('type') in target_types]

 
    filtered_filings = SECFilingsTools.filter_sec_filings(filtered_filings)

    return {'financial_event_filings': filtered_filings}

# %%
tsla = get_financial_event_filings('TSLA')

# %%
tsla['financial_event_filings']

msft_type_counter = Counter(d.get('type') for d in tsla['financial_event_filings'] if 'type' in d)
print(msft_type_counter)
# Out:
# Counter({'8-K': 34, '10-Q': 9, '10-K': 4, '8-K/A': 1, '10-K/A': 1})
